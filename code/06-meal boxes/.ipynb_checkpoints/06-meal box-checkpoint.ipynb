# %%
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler
import numpy as np
import pylab
# %matplotlib inline
import matplotlib.pyplot as p 
p.show()
import re

# %%
plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'axes.prop_cycle': cycler('color', ['#BA4D49']),#,'#4D6168','#F06560','#83A8AE','#E6B0A4','#C9CFAD']),
    'axes.spines.left'   : True,   
    'axes.spines.bottom' : False,
    'axes.spines.top'    : False,
    'axes.spines.right'  : False,
    'axes.labelcolor'  :'#4D6168',
    'axes.grid'           : True,
    'axes.axisbelow'      : True,
    
    'font.sans-serif': 'Arial Rounded MT Bold',
    'font.family': 'sans-serif',
    
    'text.color': '#4D6168',
    
    'xtick.color' : '#4D6168',
    'ytick.color' : '#4D6168',
    
    'grid.color':  '#83A8AE',
    
    'legend.edgecolor': 'white',
 
})

# %%
df = pd.read_csv("Ruokatilausexcel.csv")

# %%
df
# Out:
#           Firm  Price Meat 2  Price Meat 4  Price Veg 2  Price Veg 4  \
# 0   Blue Apron          9.99          7.99         9.99         7.99
# 1   Green Chef         13.49         12.99        10.49          NaN
# 2   Sun Basket         11.99         11.99        11.99        11.99
# 3  Hello Fresh          7.99          6.99         7.99         7.99
#
#    Meal 1 Cal  Meal 1 Prot Meal 1 Salt Meal 1 Fat  Meal 2 Cal  \
# 0         720           40          52         51         640
# 1         830           47          31         23         650
# 2         430           38         NaN         40         480
# 3         670           47       830mg        28g         880
#
#                          ...                          Veg 1 Fat Veg 2 Cal  \
# 0                        ...                                 46       970
# 1                        ...                                 33       540
# 2                        ...                                 40       560
# 3                        ...                                28g       740
#
#   Veg 2 Prot  Veg 2 Salt  Veg 2 Fat Veg 3 Cal Veg 3 Prot  Veg 3 Salt  \
# 0         20          45         78       590         25          61
# 1         24          47         28       730         33          31
# 2         39         NaN         28       680         26         NaN
# 3         36       520mg        29g       490         13       590mg
#
#    Veg 3 Fat                                              Notes
# 0         54                                                NaN
# 1         41                                                NaN
# 2         65  suolaa ei voi laittaa koska itse lisättyä ei o...
# 3        17g                                                NaN
#
# [4 rows x 30 columns]

# %%
df['meat_prot'] = round((df['Meal 1 Prot'] + df['Meal 2 Prot'] + df['Meal 3 Prot'])/3)

# %%
df
# Out:
#           Firm  Price Meat 2  Price Meat 4  Price Veg 2  Price Veg 4  \
# 0   Blue Apron          9.99          7.99         9.99         7.99
# 1   Green Chef         13.49         12.99        10.49          NaN
# 2   Sun Basket         11.99         11.99        11.99        11.99
# 3  Hello Fresh          7.99          6.99         7.99         7.99
#
#    Meal 1 Cal  Meal 1 Prot Meal 1 Salt Meal 1 Fat  Meal 2 Cal    ...     \
# 0         720           40          52         51         640    ...
# 1         830           47          31         23         650    ...
# 2         430           38         NaN         40         480    ...
# 3         670           47       830mg        28g         880    ...
#
#    Veg 2 Cal Veg 2 Prot Veg 2 Salt  Veg 2 Fat  Veg 3 Cal Veg 3 Prot  \
# 0        970         20         45         78        590         25
# 1        540         24         47         28        730         33
# 2        560         39        NaN         28        680         26
# 3        740         36      520mg        29g        490         13
#
#   Veg 3 Salt  Veg 3 Fat                                              Notes  \
# 0         61         54                                                NaN
# 1         31         41                                                NaN
# 2        NaN         65  suolaa ei voi laittaa koska itse lisättyä ei o...
# 3      590mg        17g                                                NaN
#
#   meat_prot
# 0      41.0
# 1      38.0
# 2      38.0
# 3      42.0
#
# [4 rows x 31 columns]

# %%
df['veg_prot'] = round((df['Veg 1 Prot'] + df['Veg 2 Prot'] + df['Veg 3 Prot'])/3)
df
# Out:
#           Firm  Price Meat 2  Price Meat 4  Price Veg 2  Price Veg 4  \
# 0   Blue Apron          9.99          7.99         9.99         7.99
# 1   Green Chef         13.49         12.99        10.49          NaN
# 2   Sun Basket         11.99         11.99        11.99        11.99
# 3  Hello Fresh          7.99          6.99         7.99         7.99
#
#    Meal 1 Cal  Meal 1 Prot Meal 1 Salt Meal 1 Fat  Meal 2 Cal   ...     \
# 0         720           40          52         51         640   ...
# 1         830           47          31         23         650   ...
# 2         430           38         NaN         40         480   ...
# 3         670           47       830mg        28g         880   ...
#
#    Veg 2 Prot Veg 2 Salt Veg 2 Fat  Veg 3 Cal  Veg 3 Prot Veg 3 Salt  \
# 0          20         45        78        590          25         61
# 1          24         47        28        730          33         31
# 2          39        NaN        28        680          26        NaN
# 3          36      520mg       29g        490          13      590mg
#
#   Veg 3 Fat                                              Notes  meat_prot  \
# 0        54                                                NaN       41.0
# 1        41                                                NaN       38.0
# 2        65  suolaa ei voi laittaa koska itse lisättyä ei o...       38.0
# 3       17g                                                NaN       42.0
#
#   veg_prot
# 0     22.0
# 1     25.0
# 2     30.0
# 3     26.0
#
# [4 rows x 32 columns]

# %%
df['meat_prot_price'] = round(df['Price Meat 2']/df['meat_prot'],2)
df['veg_prot_price'] = round(df['Price Veg 2']/df['veg_prot'],2)
df
# Out:
#           Firm  Price Meat 2  Price Meat 4  Price Veg 2  Price Veg 4  \
# 0   Blue Apron          9.99          7.99         9.99         7.99
# 1   Green Chef         13.49         12.99        10.49          NaN
# 2   Sun Basket         11.99         11.99        11.99        11.99
# 3  Hello Fresh          7.99          6.99         7.99         7.99
#
#    Meal 1 Cal  Meal 1 Prot Meal 1 Salt Meal 1 Fat  Meal 2 Cal      ...        \
# 0         720           40          52         51         640      ...
# 1         830           47          31         23         650      ...
# 2         430           38         NaN         40         480      ...
# 3         670           47       830mg        28g         880      ...
#
#    Veg 2 Fat Veg 3 Cal Veg 3 Prot  Veg 3 Salt  Veg 3 Fat  \
# 0         78       590         25          61         54
# 1         28       730         33          31         41
# 2         28       680         26         NaN         65
# 3        29g       490         13       590mg        17g
#
#                                                Notes meat_prot  veg_prot  \
# 0                                                NaN      41.0      22.0
# 1                                                NaN      38.0      25.0
# 2  suolaa ei voi laittaa koska itse lisättyä ei o...      38.0      30.0
# 3                                                NaN      42.0      26.0
#
#    meat_prot_price veg_prot_price
# 0             0.24           0.45
# 1             0.36           0.42
# 2             0.32           0.40
# 3             0.19           0.31
#
# [4 rows x 34 columns]

# %%
df.plot(x='Price Meat 2', y='meat_prot', kind='scatter')

# %%
df.plot(x='Price Veg 2', y='veg_prot', kind='scatter')

# %%
df_blue = pd.read_csv("blueapron_salt.csv")

# %%
df_blue
# Out:
#        Company  Veg  Salt                                   Food
# 0   Blue Apron   No    39         Seared Steak on Cheese Polenta
# 1   Blue Apron   No    50                      Tuscan Pork Chops
# 2   Blue Apron  Yes    53               Crispy Veese Quesadillas
# 3   Blue Apron   No    43                Blackened Cajun Chicken
# 4   Blue Apron   No    80                 Shrimp & Pesto Cnocchi
# 5   Blue Apron   No    46              Spiced Chicken & Couscous
# 6   Blue Apron   No    34  Seared Cod & Peppers over Creamy Rice
# 7   Blue Apron  Yes    28           Sicilian-Style Orecchierette
# 8   Blue Apron   No    38      Seared Steaks over Cheese Polenta
# 9   Blue Apron   No    67           Spicy BBQ Chicken Drumsticks
# 10  Blue Apron  Yes    72             Sweet & Spicy Soba Noodles
# 11  Blue Apron   No    53                    Sweet Chili Chicken
# 12  Blue Apron  Yes    36       Whole Grain Pasta & Tomato Sauce
# 13  Blue Apron  Yes    45                     Vegetable Tostadas
# 14  Blue Apron   No    77        Spicy Soy-Glazed Chicken Thighs
# 15  Blue Apron   No    41     Tuscan Chicken & Summer Vegetables
# 16  Blue Apron   No    83                        Vadouvan Shrimp
# 17  Blue Apron   No    52                          Beef Stir-Fry
# 18  Blue Apron   No    65      Sour Cherry-Glazed Chicken Thighs
# 19  Blue Apron   No    48      Cheeseburgers with Cucumber Salsa

# %%
veg_type = []

for row in df_blue.Veg:
    if row in ['No']:
        veg_type.append(1)
    else:
        veg_type.append(2)

df_blue['veg_type'] = veg_type

# %%
df_blue
# Out:
#        Company  Veg  Salt                                   Food  veg_type
# 0   Blue Apron   No    39         Seared Steak on Cheese Polenta         1
# 1   Blue Apron   No    50                      Tuscan Pork Chops         1
# 2   Blue Apron  Yes    53               Crispy Veese Quesadillas         2
# 3   Blue Apron   No    43                Blackened Cajun Chicken         1
# 4   Blue Apron   No    80                 Shrimp & Pesto Cnocchi         1
# 5   Blue Apron   No    46              Spiced Chicken & Couscous         1
# 6   Blue Apron   No    34  Seared Cod & Peppers over Creamy Rice         1
# 7   Blue Apron  Yes    28           Sicilian-Style Orecchierette         2
# 8   Blue Apron   No    38      Seared Steaks over Cheese Polenta         1
# 9   Blue Apron   No    67           Spicy BBQ Chicken Drumsticks         1
# 10  Blue Apron  Yes    72             Sweet & Spicy Soba Noodles         2
# 11  Blue Apron   No    53                    Sweet Chili Chicken         1
# 12  Blue Apron  Yes    36       Whole Grain Pasta & Tomato Sauce         2
# 13  Blue Apron  Yes    45                     Vegetable Tostadas         2
# 14  Blue Apron   No    77        Spicy Soy-Glazed Chicken Thighs         1
# 15  Blue Apron   No    41     Tuscan Chicken & Summer Vegetables         1
# 16  Blue Apron   No    83                        Vadouvan Shrimp         1
# 17  Blue Apron   No    52                          Beef Stir-Fry         1
# 18  Blue Apron   No    65      Sour Cherry-Glazed Chicken Thighs         1
# 19  Blue Apron   No    48      Cheeseburgers with Cucumber Salsa         1

# %%
df_blue.groupby(['Veg']).Salt.mean()
# Out:
# Veg
# No     54.4
# Yes    46.8
# Name: Salt, dtype: float64

# %%
ax = df_blue.plot(x='veg_type', y='Salt', kind='scatter')
ax

# %%
ax = df_blue.plot(x='veg_type', y='Salt', kind='scatter')
ax

ax.set_title("Too much salt in meal box delivery meals", pad=10, fontsize=20, loc='left')
ax.set_xticks([1,2])
ax.set_xticklabels(["Omnivore", "Vegetarian"])
ax.set_yticks([25, 35, 40,60,80])
ax.set_yticklabels(["heart-healthy level: 25", "recommended level: 35", "40", "60", "80"])

ax.grid(False, axis='x')
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
#ax.grid(False, axis='y')
#ax.tick_params(labeltop=True, labelbottom=False)
#ax.tick_params(left=False)
#ax.tick_params(bottom=False)
#plt.gcf().text(0.12, 0.98, "Number of deaths caused by foodborne outbreaks from 1998 to 2016", ha='left', fontsize=12)
#"Number of deaths caused by foodborne outbreaks from 1998 to 2016"
#plt.savefig("foodkills1_allfoods.pdf", transparent=True)

# %%
df_test = pd.read_csv("test.csv", sep=';')

# %%
df_test
# Out:
#             Nutrition Facts                Unnamed: 1 Unnamed: 2
# 0                       NaN                       NaN        NaN
# 1   2 serving per container                       NaN        NaN
# 2        Serving size(436g)                       NaN        NaN
# 3        Amount per serving                       NaN        NaN
# 4               Calories590                       NaN        NaN
# 5            % Daily Value*                       NaN        NaN
# 6             Total Fat 16g                      21 %        NaN
# 7                       NaN        Saturated Fat 1.5g        8 %
# 8                       NaN              Trans Fat 0g        NaN
# 9          Cholesterol 65mg                      22 %        NaN
# 10             Sodium 790mg                      34 %        NaN
# 11   Total Carbohydrate 58g                      21 %        NaN
# 12                      NaN          Dietary Fiber 8g       29 %
# 13                      NaN          Total Sugars 15g        NaN
# 14                      NaN  Includes 5g Added Sugars       10 %
# 15              Protein 53g                       NaN        NaN
# 16           Vitamin D 3mcg                      15 %        NaN
# 17            Calcium 123mg                      10 %        NaN
# 18                 Iron 5mg                      30 %        NaN
# 19         Potassium 1538mg                      35 %        NaN

# %%
gc_omni = open("greenchef_omni.txt").read()
gc_vege = open("greenchef_vege.txt").read()

# %%
gc_omni
# Out:
# '\ufeff;;\n;;\nSESAME-CRUSTED TUNA;;\nServing size(436g);;\nAmount per serving;;\nCalories590;;\n% Daily Value*;;\nTotal Fat\xa016g;21 %;\n;Saturated Fat 1.5g;8 %\n;Trans\xa0Fat 0g;\nCholesterol\xa065mg;22 %;\nSodium\xa0790mg;34 %;\nTotal Carbohydrate\xa058g;21 %;\n;Dietary Fiber 8g;29 %\n;Total Sugars 15g;\n;Includes 5g Added Sugars;10 %\nProtein\xa053g;;\nVitamin D 3mcg;15 %;\nCalcium 123mg;10 %;\nIron 5mg;30 %;\nPotassium 1538mg;35 %;\nMOLE-SPICED STEAK;;\nServing size(471g);;\nAmount per serving;;\nCalories430;;\n% Daily Value*;;\nTotal Fat\xa013g;17 %;\n;Saturated Fat 7g;35 %\n;Trans\xa0Fat 0g;\nCholesterol\xa085mg;28 %;\nSodium\xa0430mg;19 %;\nTotal Carbohydrate\xa040g;15 %;\n;Dietary Fiber 7g;25 %\n;Total Sugars 11g;\n;Includes 0g Added Sugars;0 %\nProtein\xa038g;;\nVitamin D 0mcg;0 %;\nCalcium 124mg;10 %;\nIron 5mg;30 %;\nPotassium 1281mg;30 %;\n* The % Daily Value (DV) tells you how much a nutrient in a serving of food contributes to a daily diet. 2,000 calories a day is used for general nutrition advice.;;\nMEDITERRANEAN STUFFED ZUCCHINI;;\nServing size(565g);;\nAmount per serving;;\nCalories620;;\n% Daily Value*;;\nTotal Fat\xa033g;42 %;\n;Saturated Fat 6g;30 %\n;Trans\xa0Fat 0g;\nCholesterol\xa020mg;7 %;\nSodium\xa0480mg;21 %;\nTotal Carbohydrate\xa065g;24 %;\n;Dietary Fiber 10g;36 %\n;Total Sugars 18g;\n;Includes 0g Added Sugars;0 %\nProtein\xa018g;;\nVitamin D 0mcg;0 %;\nCalcium 243mg;20 %;\nIron 5mg;30 %;\nPotassium 1027mg;20 %;\nROASTED SAUSAGES & SAUERKRAUT;;\nServing size(364g);;\nAmount per serving;;\nCalories540;;\n% Daily Value*;;\nTotal Fat\xa042g;54 %;\n;Saturated Fat 10g;50 %\n;Trans\xa0Fat 0g;\nCholesterol\xa055mg;18 %;\nSodium\xa0910mg;40 %;\nTotal Carbohydrate\xa022g;8 %;\n;Dietary Fiber 5g;18 %\n;Total Sugars 7g;\n;Includes 0g Added Sugars;0 %\nProtein\xa022g;;\nVitamin D 0mcg;0 %;\nCalcium 141mg;10 %;\nIron 2mg;10 %;\nPotassium 673mg;15 %;\nSESAME CHICKEN STIR-FRY;;\nServing size(458g);;\nAmount per serving;;\nCalories460;;\n% Daily Value*;;\nTotal Fat\xa011g;14 %;\n;Saturated Fat 2g;10 %\n;Trans\xa0Fat 0g;\nCholesterol\xa0240mg;80 %;\nSodium\xa0590mg;26 %;\nTotal Carbohydrate\xa041g;15 %;\n;Dietary Fiber 5g;18 %\n;Total Sugars 16g;\n;Includes 5g Added Sugars;10 %\nProtein\xa045g;;\nVitamin D 1mcg;6 %;\nCalcium 60mg;4 %;\nIron 2mg;10 %;\nPotassium 970mg;20 %;\nTERIYAKI PORK PATTIES;;\nServing size(392g);;\nAmount per serving;;\nCalories620;;\n% Daily Value*;;\nTotal Fat\xa043g;55 %;\n;Saturated Fat 15g;75 %\n;Trans\xa0Fat 0g;\nCholesterol\xa0130mg;43 %;\nSodium\xa0620mg;27 %;\nTotal Carbohydrate\xa026g;9 %;\n;Dietary Fiber 4g;14 %\n;Total Sugars 12g;\n;Includes 0g Added Sugars;0 %\nProtein\xa032g;;\nVitamin D 0mcg;0 %;\nCalcium 131mg;10 %;\nIron 3mg;15 %;\nPotassium 234mg;4 %;\nMOZZARELLA-STUFFED MEATLOAVES;;\nServing size(393g);;\nAmount per serving;;\nCalories450;;\n% Daily Value*;;\nTotal Fat\xa023g;29 %;\n;Saturated Fat 10g;50 %\n;Trans\xa0Fat 1g;\nCholesterol\xa0130mg;43 %;\nSodium\xa0640mg;28 %;\nTotal Carbohydrate\xa015g;5 %;\n;Dietary Fiber 3g;11 %\n;Total Sugars 6g;\n;Includes 0g Added Sugars;0 %\nProtein\xa045g;;\nVitamin D 0mcg;0 %;\nCalcium 296mg;25 %;\nIron 6mg;35 %;\nPotassium 1178mg;25 %;\nGRILLED PERSIAN CHICKEN SALAD;;\nServing size(477g);;\nAmount per serving;;\nCalories410;;\n% Daily Value*;;\nTotal Fat\xa021g;27 %;\n;Saturated Fat 2.5g;13 %\n;Trans\xa0Fat 0g;\nCholesterol\xa095mg;32 %;\nSodium\xa0200mg;9 %;\nTotal Carbohydrate\xa016g;6 %;\n;Dietary Fiber 6g;21 %\n;Total Sugars 4g;\n;Includes 0g Added Sugars;0 %\nProtein\xa045g;;\nVitamin D 0mcg;0 %;\nCalcium 84mg;6 %;\nIron 3mg;15 %;\nPotassium 465mg;10 %;\nPESTO PASTA PRIMAVERA;;\nServing size(518g);;\nAmount per serving;;\nCalories700;;\n% Daily Value*;;\nTotal Fat\xa037g;47 %;\n;Saturated Fat 7g;35 %\n;Trans\xa0Fat 0g;\nCholesterol\xa0135mg;45 %;\nSodium\xa0450mg;20 %;\nTotal Carbohydrate\xa073g;27 %;\n;Dietary Fiber 6g;21 %\n;Total Sugars 11g;\n;Includes 2g Added Sugars;4 %\nProtein\xa024g;;\nVitamin D 1mcg;6 %;\nCalcium 363 ...

# %%
gc_omni_salt = re.findall(r"Sodium\s(\d\d\d\d?)", gc_omni)

# %%
gc_vege_salt = re.findall(r"Sodium\s(\d\d\d\d?)", gc_vege)

# %%
df_gc_omni = pd.DataFrame(gc_omni_salt)

# %%
df_gc_omni['veg_type'] = 1
df_gc_omni
# Out:
#       0  veg_type
# 0   790         1
# 1   430         1
# 2   480         1
# 3   910         1
# 4   590         1
# 5   620         1
# 6   640         1
# 7   200         1
# 8   450         1
# 9  1270         1

# %%
df_gc_vege = pd.DataFrame(gc_vege_salt)
df_gc_vege['veg_type'] = 2
df_gc_vege
# Out:
#        0  veg_type
# 0   1270         2
# 1    930         2
# 2   1000         2
# 3    940         2
# 4    470         2
# 5    450         2
# 6    480         2
# 7   1070         2
# 8    710         2
# 9   1390         2
# 10   580         2
# 11   930         2

# %%
frames = [df_gc_omni,df_gc_vege]
df_gc = pd.concat(frames)
df_gc
# Out:
#        0  veg_type
# 0    790         1
# 1    430         1
# 2    480         1
# 3    910         1
# 4    590         1
# 5    620         1
# 6    640         1
# 7    200         1
# 8    450         1
# 9   1270         1
# 0   1270         2
# 1    930         2
# 2   1000         2
# 3    940         2
# 4    470         2
# 5    450         2
# 6    480         2
# 7   1070         2
# 8    710         2
# 9   1390         2
# 10   580         2
# 11   930         2

# %%
df_gc=df_gc.rename(columns = {0 :'salt'})
df_gc
# Out:
#     salt  veg_type
# 0    790         1
# 1    430         1
# 2    480         1
# 3    910         1
# 4    590         1
# 5    620         1
# 6    640         1
# 7    200         1
# 8    450         1
# 9   1270         1
# 0   1270         2
# 1    930         2
# 2   1000         2
# 3    940         2
# 4    470         2
# 5    450         2
# 6    480         2
# 7   1070         2
# 8    710         2
# 9   1390         2
# 10   580         2
# 11   930         2

# %%
df_gc['salt'] = df_gc['salt'].apply(pd.to_numeric)

# %%
df_gc.dtypes
# Out:
# salt        int64
# veg_type    int64
# dtype: object

# %%
ax_gc = df_gc.plot(x='veg_type', y='salt', kind='scatter')
ax_gc

ax_gc.set_title("Green Chef: balanced salt", pad=10, fontsize=20, loc='left')
ax_gc.set_xticks([1,2])
ax_gc.set_xticklabels(["Omnivore", "Vegetarian"])
ax_gc.set_yticks([850])
ax_gc.set_yticklabels(["healthy level:\n850 mg of sodium"])

ax_gc.grid(False, axis='x')
ax_gc.xaxis.label.set_visible(False)
ax_gc.yaxis.label.set_visible(False)
