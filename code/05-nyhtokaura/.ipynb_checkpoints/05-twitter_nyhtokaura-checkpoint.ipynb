# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from cycler import cycler
import numpy as np

# %matplotlib inline

# %%
plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'axes.prop_cycle': cycler('color', ['#BA4D49']),#,'#4D6168','#F06560','#83A8AE','#E6B0A4','#C9CFAD']),
    'axes.spines.left'   : True,   
    'axes.spines.bottom' : False,
    'axes.spines.top'    : False,
    'axes.spines.right'  : False,
    'axes.labelcolor'  :'#4D6168',
    'axes.grid'           : True,
    'axes.axisbelow'      : True,
    
    'font.sans-serif': 'Arial Rounded MT Bold',
    'font.family': 'sans-serif',
    
    'text.color': '#4D6168',
    
    'xtick.color' : '#4D6168',
    'ytick.color' : '#4D6168',
    
    'grid.color':  '#83A8AE',
    
    'legend.edgecolor': 'white',
 
})

# %%
fb = open("nyhtokauratutka_fb.txt").read()

# %%
fb
# Out:
# 'regex päivämääriä varten\n\\w*\\s\\d*\\d,\\s201\\d\nFacebook\n\n\n\nNyhtökauratutka\n\nPäivi\nHome\nFriend Requests\nMessages\n1\nNotifications\nAccount Settings\nNyhtökauratutka\nPublic Group\nAbout\nDiscussion\nMembers\nEvents\nVideos\nPhotos\n\nSearch this group\nSearch this group\nShortcuts\n\nColumbia Journalism School Class of 2019\n1\n\nSuomalaiset lapsiperheet New Yorkissa\n1\n\nThe Eat Your Books Cookbook Club\n13\n\n#CJSGlobal\n4\n\nThe Cookbook Junkies\n20+\n\nUpper West Side Parents\n20+\n\nKestovaipat ja kantovälineet kiertoon, (O)sta -(M)yy - (V)aihda\n20+\n\nHS-journalismi aina!\n2\n\nAmerikansuomalaisten Markkinapaikka\n16\n\nMutsit Vs Faijat\n20+\n\nKansainvälinen ruokapirtti\n20+\n\nSwansean Suomalaiset\n\nKallio kierrättää lastenvaatteet ja -tarvikkeet\n20+\nSee more\n\n\nJoined\nNotifications\nShare\nsettingsMore\nADD MEMBERS\n\nEnter name or email address...\nnote\n1,787 Members\nMEMBERS\n\n\n\n\n\n\nSUGGESTED MEMBERS\nHide\nSUGGESTED MEMBERS\nFriends\n\nAdd Member\nMinna Auvinen\n\nAdd Member\nMilla Järvinen Os Ala-Risku\n\nAdd Member\nHenna Ala-Risku Os Yli-Risku\nSee More\nDESCRIPTION\nDESCRIPTION\nJos näet nyhtökauraa, ilmoita nyhtishimoitsijoille.\n\nKyllä vegaanikin saalistaa.\nSaalistamme nyhtökauraa.\nCREATE NEW GROUPS\nGroups make it easier than ever to share with friends, family and teammates.\nCreate Group\nRECENT GROUP PHOTOSSee All\nLumikukka Ajaton\'s photo.\nSatu Lumme\'s photo.\nKatianna Sivonen\'s photo.\nSuggested Groups\nSee All\n\'Hih, @[530884657:2048:Saara Kurkela] :D Kiitos letkautuksesta!\'\nVegaaninen ruokatuki\n1,926 members\nJoin\nSofia Tervola\'s photo.\nVegaanin vaatetus\n979 members\nJoin\nMarja-Liisa Lähteinen\'s photo.\n\n\n\n\n\n\nVegaanituotteet\n3 friends · 6,485 members\nJoin\n\nVegaaninen leivonta\n1,664 members\nJoin\nAnne Kortesniemi\'s photo.\nVegaanien roskalava\n1,943 members\nJoin\nRecommended for You Nearby\n\nWheeled portable AC unit\n$80 · New York, NY\nView Details\nSee More on Marketplace\nSuggested Pages\nSee All\n5.0\n5 out of 5 · $ · Always Open\n\nMNJ Property Maintenance\nProperty Management Company · Local Service\nMNJ Property Maintenance\'s photo.\nLike Page\nEnglish (US) · Suomi · Deutsch · Español · Svenska\nPrivacy · Terms · Advertising · Ad Choices · Cookies · \nMore\nFacebook © 2018\n \nWrite PostAdd Photo/VideoLive Video\nMore\n\n\nWrite something...\nPhoto/Video\n\nGet Together\nWatch Party\nPINNED POST\n\nVanessa Lindström\nJuly 19, 2016\nTervetuloa nyhtökauratutkaan.\nJos saat tietoosi, mistä tätä paljoa puhuttua nyhtökauraa on saatavilla, ilmoita tarkka paikka(sijainti käy myös), jonkinnäköinen aika sekä jos mahdollista, pakettien määrä ja miltä hyllyltä löytyy. Ilmoituksen voi myös tehdä vaikka ei itse olisi paikan päällä. Pyritään kuitenkin aina antamaan mahdollisimman tarkat ohjeet että saadaan nyhtishimoitsijat perille saakka!\n\nSAATAVUUS:\nTässä paikkoja ja ajankohtia joita kannattaa käydä tsekkaamassa! ...\nSee More\n2 Comments\n3131\nLike\nComment\nShare\nNews Feed\nRECENT ACTIVITY\n\nEvan Emad shared a live video.\nJuly 7\n\nPlay0:07 / 1:17:56  \nAdditional Visual Settings\nEnter Watch And ScrollClick to enlarge  Unmute\n17,652 Views\nRadio Espoo International was live.Like Page\nJuly 7\nاستقبال الفنان سيف نبيل مطار فانتا - هلسنكي مساء اليوم 7/7\n\nSee Translation\nLike\nComment\nShare\nComments\nPäivi Ala-Risku\n\nWrite a comment...\n\n\nOLDER\n\nSuvi Kerttula\nNovember 5, 2017\nMissä Helsingissä on uusia nyhtökaurapyöryköitä? Tiedän S ja K-kaupat, mutta en ole vielä missään nähnyt\n5 Comments\nLike\nComment\nShare\nComments\nNina Liljeblad\nNina Liljeblad Mä oon nähny ainakin arabian S-marketissa, ne ei ainakaan siellä ollut nyhtökauran vieressä vaan eineslihapullien vieressä.\nManage\nLike · Reply · 40w\nLaura Toikkari\nLaura Toikkari Kaaren Prismassa oon muistaakseni nähny. Ja Juvankartanon S-marketissa Espoossa. Luulis siis löytyvän ainakin isommista S-kaupoista. Ja juurikin lihapulla- tms. osastolla.\nManage\nLike · Reply · 4 ...

# %%
#fb = fb.split('\n')

# %%
#fb

# %%
type(fb)
# Out:
# str

# %%
dates = re.findall(r"\w*\s\d*\d,\s201\d", fb)
dates
# Out:
# ['July 19, 2016',
#  'November 5, 2017',
#  'October 9, 2017',
#  'October 9, 2017',
#  'October 5, 2017',
#  'September 23, 2017',
#  'September 11, 2017',
#  'September 1, 2017',
#  'July 14, 2017',
#  'June 25, 2017',
#  'May 18, 2017',
#  'April 28, 2017',
#  'May 6, 2017',
#  'May 5, 2017',
#  'May 4, 2017',
#  'April 29, 2017',
#  'April 29, 2017',
#  'April 28, 2017',
#  'April 27, 2017',
#  'April 25, 2017',
#  'April 25, 2017',
#  'April 23, 2017',
#  'April 18, 2017',
#  'April 17, 2017',
#  'April 13, 2017',
#  'April 12, 2017',
#  'April 12, 2017',
#  'April 12, 2017',
#  'April 11, 2017',
#  'April 10, 2017',
#  'April 10, 2017',
#  'April 10, 2017',
#  'April 8, 2017',
#  'April 8, 2017',
#  'April 8, 2017',
#  'April 7, 2017',
#  'April 7, 2017',
#  'April 7, 2017',
#  'April 2, 2017',
#  'April 1, 2017',
#  'March 31, 2017',
#  'March 31, 2017',
#  'March 30, 2017',
#  'March 29, 2017',
#  'March 28, 2017',
#  'March 27, 2017',
#  'March 27, 2017',
#  'March 27, 2017',
#  'March 27, 2017',
#  'March 25, 2017',
#  'March 26, 2017',
#  'March 24, 2017',
#  'March 25, 2017',
#  'March 25, 2017',
#  'March 23, 2017',
#  'March 24, 2017',
#  'March 24, 2017',
#  'March 24, 2017',
#  'March 23, 2017',
#  'March 23, 2017',
#  'March 22, 2017',
#  'March 20, 2017',
#  'March 19, 2017',
#  'March 18, 2017',
#  'March 17, 2017',
#  'March 17, 2017',
#  'March 17, 2017',
#  'March 17, 2017',
#  'March 17, 2017',
#  'March 17, 2017',
#  'March 15, 2017',
#  'March 15, 2017',
#  'March 14, 2017',
#  'March 14, 2017',
#  'March 12, 2017',
#  'March 13, 2017',
#  'March 12, 2017',
#  'March 12, 2017',
#  'March 12, 2017',
#  'March 11, 2017',
#  'March 11, 2017',
#  'March 10, 2017',
#  'March 10, 2017',
#  'March 10, 2017',
#  'March 4, 2017',
#  'March 4, 2017',
#  'March 3, 2017',
#  'March 3, 2017',
#  'February 27, 2017',
#  'February 27, 2017',
#  'February 26, 2017',
#  'February 24, 2017',
#  'February 24, 2017',
#  'February 23, 2017',
#  'February 22, 2017',
#  'February 22, 2017',
#  'February 22, 2017',
#  'February 20, 2017',
#  'February 19, 2017',
#  'February 18, 2017',
#  'February 18, 2017',
#  'February 17, 2017',
#  'February 16, 2017',
#  'February 16, 2017',
#  'February 15, 2017',
#  'February 14, 2017',
#  'February 13, 2017',
#  'February 13, 2017',
#  'February 12, 2017',
#  'February 12, 2017',
#  'February 11, 2017',
#  'February 9, 2017',
#  'February 8, 2017',
#  'February 7, 2017',
#  'February 7, 2017',
#  'February 3, 2017',
#  'February 3, 2017',
#  'January 29, 2017',
#  'January 18, 2017',
#  'January 27, 2017',
#  'January 27, 2017',
#  'January 27, 2017',
#  'January 26, 2017',
#  'January 21, 2017',
#  'January 21, 2017',
#  'January 21, 2017',
#  'January 20, 2017',
#  'January 20, 2017',
#  'January 20, 2017',
#  'January 20, 2017',
#  'January 19, 2017',
#  'January 18, 2017',
#  'January 13, 2017',
#  'January 13, 2017',
#  'January 9, 2017',
#  'January 7, 2017',
#  'January 7, 2017',
#  'January 7, 2017',
#  'January 4, 2017',
#  'January 3, 2017',
#  'December 29, 2016',
#  'December 22, 2016',
#  'December 17, 2016',
#  'December 25, 2016',
#  'December 22, 2016',
#  'December 23, 2016',
#  'December 23, 2016',
#  'December 23, 2016',
#  'December 21, 2016',
#  'December 22, 2016',
#  'December 21, 2016',
#  'December 21, 2016',
#  'December 21, 2016',
#  'December 21, 2016',
#  'December 20, 2016',
#  'December 19, 2016',
#  'December 18, 2016',
#  'December 18, 2016',
#  'December 17, 2016',
#  'December 17, 2016',
#  'December 17, 2016',
#  'December 17, 2016',
#  'December 16, 2016',
#  'December 16, 2016',
#  'December 16, 2016',
#  'December 16, 2016',
#  'December 13, 2016',
#  'December 13, 2016',
#  'December 9, 2016',
#  'December 12, 2016',
#  'December 13, 2016',
#  'December 13, 2016',
#  'December 13, 2016',
#  'December 11, 2016',
#  'December 10, 2016',
#  'December 10, 2016',
#  'December 10, 2016',
#  'December 10, 2016',
#  'December 10, 2016',
#  'December 9, 2016',
#  'December 9, 2016',
#  'December 5, 2016',
#  'December 5, 2016',
#  'December 5, 2016',
#  'December 5, 2016',
#  'December 4, 2016',
#  'December 4, 2016',
#  'December 4, 2016',
#  'December 4, 2016',
#  'December 3, 2016',
#  'December 3, 2016',
#  'December 3, 2016',
#  'December 3, 2016',
#  'December 3, 2016',
#  'December 3, 2016',
#  'December 3, 2016',
#  'December 3, 2016',
#  'December 2, 2016',
#  'December 2, 2016',
#  'December 2, 2016',
#  'December 2, 2016',
#  'December 2, 2016',
#  'December 1, 2016',
#  'November 28, 2016',
#  'November 27, 2016',
#  'November 27, 2016',
#  'November 26, 2016',
#  'November 24, 2016',
#  'November 25, 2016',
#  'November 25, 2016',
#  'November 25, 2016',
#  'November 24, 2016',
#  'November 22, 2016',
#  'November 19, 2016',
#  'November 17, 2016',
#  'November 21, 2016',
#  'November 20, 2016',
#  'November 20, 2016',
#  'November 17, 2016',
#  'November 19, 2016',
#  'November 18, 2016',
#  'November 19, 2016',
#  'November 19, 2016',
#  'November 19, 2016',
#  'November 19, 2016',
#  'November 19, 2016',
#  'November 19, 2016',
#  'November 18, 2016',
#  'November 18, 2016',
#  'November 18, 2016',
#  'November 18, 2016',
#  'November 18, 2016',
#  'November 18, 2016',
#  'November 18, 2016',
#  'November 16, 2016',
#  'November 16, 2016',
#  'November 16, 2016',
#  'November 13, 2016',
#  'November 14, 2016',
#  'November 13, 2016',
#  'November 13, 2016',
#  'November 13, 2016',
#  'November 12, 2016',
#  'November 12, 2016',
#  'November 12, 2016',
#  'November 12, 2016',
#  'November 12, 2016',
#  'November 11, 2016',
#  'November 9, 2016',
#  'November 11, 2016',
#  'November 11, 2016',
#  'November 11, 2016',
#  'November 9, 2016',
#  'November 10, 2016',
#  'November 10, 2016',
#  'November 10, 2016',
#  'November 8, 2016',
#  'November 9, 2016',
#  'November 9, 2016',
#  'November 9, 2016',
#  'November 6, 2016',
#  'November 7, 2016',
#  'November 6, 2016',
#  'November 6, 2016',
#  'November 5, 2016',
#  'November 6, 2016',
#  'November 5, 2016',
#  'November 4, 2016',
#  'November 5, 2016',
#  'November 5, 2016',
#  'November 5, 2016',
#  'November 5, 2016',
#  'November 4, 2016',
#  'November 4, 2016',
#  'November 4, 2016',
#  'November 4, 2016',
#  'November 4, 2016',
#  'November 4, 2016',
#  'November 4, 2016',
#  'November 1, 2016',
#  'October 30, 2016',
#  'October 20, 2016',
#  'October 19, 2016',
#  'October 29, 2016',
#  'October 29, 2016',
#  'October 29, 2016',
#  'October 21, 2016',
#  'October 22, 2016',
#  'October 26, 2016',
#  'October 29, 2016',
#  'October 29, 2016',
#  'October 29, 2016',
#  'October 29, 2016',
#  'October 28, 2016',
#  'October 28, 2016',
#  'October 28, 2016',
#  'October 28, 2016',
#  'October 28, 2016',
#  'October 23, 2016',
#  'October 23, 2016',
#  'October 12, 2016',
#  'October 12, 2016',
#  'October 22, 2016',
#  'October 22, 2016',
#  'October 22, 2016',
#  'October 18, 2016',
#  'October 21, 2016',
#  'October 21, 2016',
#  'October 21, 2016',
#  'October 20, 2016',
#  'October 15, 2016',
#  'October 19, 2016',
#  'October 19, 2016',
#  'October 12, 2016',
#  'October 19, 2016',
#  'October 16, 2016',
#  'September 22, 2016',
#  'September 21, 2016',
#  'October 4, 2016',
#  'October 13, 2016',
#  'October 15, 2016',
#  'October 15, 2016',
#  'October 15, 2016',
#  'October 14, 2016',
#  'October 14, 2016',
#  'October 14, 2016',
#  'October 13, 2016',
#  'October 13, 2016',
#  'October 13, 2016',
#  'October 10, 2016',
#  'October 9, 2016',
#  'October 9, 2016',
#  'October 8, 2016',
#  'October 7, 2016',
#  'October 8, 2016',
#  'October 8, 2016',
#  'October 7, 2016',
#  'October 7, 2016',
#  'October 7, 2016',
#  'October 7, 2016',
#  'October 7, 2016',
#  'October 7, 2016',
#  'October 7, 2016',
#  'October 4, 2016',
#  'October 4, 2016',
#  'October 4, 2016',
#  'September 30, 2016',
#  'October 2, 2016',
#  'October 2, 2016',
#  'September 23, 2016',
#  'September 28, 2016',
#  'September 30, 2016',
#  'October 1, 2016',
#  'October 1, 2016',
#  'September 30, 2016',
#  'September 28, 2016',
#  'September 30, 2016',
#  'September 29, 2016',
#  'September 27, 2016',
#  'September 26, 2016',
#  'September 28, 2016',
#  'September 25, 2016',
#  'September 24, 2016',
#  'September 24, 2016',
#  'September 24, 2016',
#  'September 24, 2016',
#  'September 24, 2016',
#  'September 24, 2016',
#  'September 20, 2016',
#  'September 23, 2016',
#  'September 23, 2016',
#  'September 23, 2016',
#  'September 21, 2016',
#  'September 21, 2016',
#  'September 21, 2016',
#  'September 19, 2016',
#  'September 20, 2016',
#  'September 20, 2016',
#  'September 14, 2016',
#  'September 17, 2016',
#  'September 17, 2016',
#  'September 17, 2016',
#  'September 17, 2016',
#  'September 17, 2016',
#  'September 17, 2016',
#  'September 16, 2016',
#  'September 16, 2016',
#  'September 16, 2016',
#  'September 16, 2016',
#  'September 16, 2016',
#  'September 16, 2016',
#  'September 16, 2016',
#  'September 16, 2016',
#  'September 15, 2016',
#  'September 14, 2016',
#  'September 13, 2016',
#  'September 13, 2016',
#  'September 13, 2016',
#  'September 12, 2016',
#  'September 12, 2016',
#  'September 12, 2016',
#  'September 11, 2016',
#  'September 10, 2016',
#  'September 9, 2016',
#  'September 10, 2016',
#  'September 10, 2016',
#  'September 10, 2016',
#  'September 9, 2016',
#  'September 9, 2016',
#  'September 9, 2016',
#  'September 6, 2016',
#  'September 3, 2016',
#  'August 31, 2016',
#  'September 5, 2016',
#  'September 4, 2016',
#  'August 20, 2016',
#  'September 4, 2016',
#  'September 4, 2016',
#  'September 4, 2016',
#  'September 3, 2016',
#  'September 3, 2016',
#  'September 2, 2016',
#  'September 3, 2016',
#  'September 3, 2016',
#  'September 3, 2016',
#  'September 3, 2016',
#  'September 3, 2016',
#  'September 3, 2016',
#  'September 3, 2016',
#  'September 3, 2016',
#  'September 2, 2016',
#  'September 2, 2016',
#  'September 2, 2016',
#  'September 2, 2016',
#  'September 2, 2016',
#  'September 2, 2016',
#  'September 1, 2016',
#  'September 1, 2016',
#  'September 1, 2016',
#  'August 30, 2016',
#  'September 1, 2016',
#  'August 31, 2016',
#  'August 31, 2016',
#  'August 31, 2016',
#  'August 31, 2016',
#  'August 31, 2016',
#  'July 29, 2016',
#  'August 30, 2016',
#  'August 25, 2016',
#  'August 29, 2016',
#  'August 29, 2016',
#  'August 27, 2016',
#  'August 27, 2016',
#  'August 27, 2016',
#  'August 27, 2016',
#  'August 27, 2016',
#  'August 27, 2016',
#  'August 26, 2016',
#  'August 27, 2016',
#  'August 23, 2016',
#  'August 26, 2016',
#  'August 26, 2016',
#  'August 25, 2016',
#  'August 23, 2016',
#  'August 25, 2016',
#  'August 24, 2016',
#  'August 24, 2016',
#  'August 24, 2016',
#  'August 24, 2016',
#  'August 24, 2016',
#  'August 24, 2016',
#  'August 24, 2016',
#  'August 23, 2016',
#  'August 20, 2016',
#  'August 20, 2016',
#  'August 20, 2016',
#  'August 13, 2016',
#  'August 19, 2016',
#  'August 19, 2016',
#  'August 19, 2016',
#  'August 19, 2016',
#  'August 19, 2016',
#  'August 19, 2016',
#  'August 19, 2016',
#  'August 17, 2016',
#  'August 16, 2016',
#  'August 10, 2016',
#  'August 17, 2016',
#  'August 17, 2016',
#  'August 16, 2016',
#  'August 15, 2016',
#  'August 15, 2016',
#  'August 13, 2016',
#  'August 13, 2016',
#  'August 13, 2016',
#  'August 13, 2016',
#  'August 13, 2016',
#  'August 13, 2016',
#  'August 13, 2016',
#  'August 12, 2016',
#  'August 10, 2016',
#  'August 12, 2016',
#  'August 12, 2016',
#  'August 9, 2016',
#  'August 10, 2016',
#  'August 10, 2016',
#  'August 10, 2016',
#  'August 10, 2016',
#  'August 10, 2016',
#  'August 5, 2016',
#  'August 9, 2016',
#  'August 9, 2016',
#  'August 9, 2016',
#  'August 9, 2016',
#  'August 9, 2016',
#  'August 4, 2016',
#  'August 8, 2016',
#  'July 28, 2016',
#  'August 6, 2016',
#  'July 28, 2016',
#  'August 6, 2016',
#  'August 6, 2016',
#  'August 6, 2016',
#  'August 6, 2016',
#  'August 6, 2016',
#  'August 6, 2016',
#  'August 6, 2016',
#  'August 6, 2016',
#  'August 6, 2016',
#  'August 6, 2016',
#  'August 2, 2016',
#  'August 5, 2016',
#  'August 5, 2016',
#  'August 5, 2016',
#  'August 5, 2016',
#  'August 5, 2016',
#  'August 5, 2016',
#  'August 5, 2016',
#  'August 5, 2016',
#  'August 5, 2016',
#  'August 5, 2016',
#  'August 5, 2016',
#  'August 4, 2016',
#  'August 4, 2016',
#  'August 4, 2016',
#  'August 3, 2016',
#  'July 28, 2016',
#  'August 2, 2016',
#  'August 2, 2016',
#  'August 2, 2016',
#  'July 23, 2016',
#  'July 31, 2016',
#  'July 28, 2016',
#  'August 1, 2016',
#  'July 30, 2016',
#  'August 1, 2016',
#  'July 28, 2016',
#  'July 31, 2016',
#  'July 28, 2016',
#  'July 31, 2016',
#  'July 31, 2016',
#  'July 31, 2016',
#  'July 31, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 30, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 28, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 29, 2016',
#  'July 28, 2016',
#  'July 15, 2016',
#  'July 28, 2016',
#  'July 28, 2016',
#  'July 28, 2016',
#  'July 28, 2016',
#  'July 28, 2016',
#  'July 28, 2016',
#  'July 28, 2016',
#  'July 28, 2016',
#  'July 28, 2016',
#  'July 15, 2016',
#  'July 23, 2016',
#  'July 27, 2016',
#  'July 26, 2016',
#  'July 23, 2016',
#  'July 23, 2016',
#  'July 22, 2016',
#  'July 23, 2016',
#  'July 23, 2016',
#  'July 15, 2016',
#  'July 22, 2016',
#  'July 22, 2016',
#  'July 22, 2016',
#  'July 22, 2016',
#  'July 22, 2016',
#  'July 19, 2016',
#  'July 19, 2016',
#  'July 19, 2016',
#  'July 16, 2016']

# %%
df = pd.DataFrame(dates, columns=['dates'])
df.head()
# Out:
#               dates
# 0     July 19, 2016
# 1  November 5, 2017
# 2   October 9, 2017
# 3   October 9, 2017
# 4   October 5, 2017

# %%
df['dates'] = pd.to_datetime(df['dates'], format="%B %d, %Y")
df.head()
# Out:
#        dates
# 0 2016-07-19
# 1 2017-11-05
# 2 2017-10-09
# 3 2017-10-09
# 4 2017-10-05

# %%
df.resample('M', on="dates").count()
# Out:
#             dates
# dates
# 2016-07-31     77
# 2016-08-31    110
# 2016-09-30     90
# 2016-10-31     68
# 2016-11-30     77
# 2016-12-31     63
# 2017-01-31     23
# 2017-02-28     29
# 2017-03-31     48
# 2017-04-30     26
# 2017-05-31      4
# 2017-06-30      1
# 2017-07-31      1
# 2017-08-31      0
# 2017-09-30      3
# 2017-10-31      3
# 2017-11-30      1

# %%
df.resample('M', on="dates").count().dates.plot()

# %%
ax_all_sw=df.resample('M', on="dates").count().dates.plot()

ax_all_sw.set_title("The Rise and Fall of the Nyhtökaura Hype", pad=20, fontsize=13, loc='left')

#ax_all_sw.yaxis.label.set_visible(False)
ax_all_sw.xaxis.label.set_visible(False)
ax_all_sw.grid(False, axis='x')
#ax_all_sw.tick_params(labeltop=True, labelbottom=False)
#ax_all_sw.tick_params(left=True)
#plt.gcf().text(0.12, 0.98, "Number of people killed by foodborne outbreaks from 1998 to 2016", ha='left', fontsize=12)
#ax_all_sw.set_xticks([2007,2008,2009,2010,2011,2012,2013,2014,2015,2016])
#ax_all_sw.set_xticklabels(["10", '20','30','40','50'])
#ax_all_sw.set_yticks([1000,10000,20000,30000])
#ax_all_sw.set_yticklabels(["1,000","10,000","20,000","30,000"])
#ax_all_sw.legend_.remove()
#ax_all_sw.tick_params(left=False, bottom=False)
plt.savefig("all_sidewalk.pdf", transparent=True)
