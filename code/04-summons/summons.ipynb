# %%
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv("summons.csv")

# %%
df.head(50)
# Out:
#                                             Violation                   Law  \
# 0                                      ACCEPT ON HAIL   Administrative Code
# 1                             AFTER HOURS CONSUMPTION                   ABC
# 2                      AGGRAVATED UNLICENSED OPERATOR                   VTL
# 3                                       ANGLE PARKING          Traffic Regs
# 4                            BARE HAND CONTACT (FOOD)           Health Code
# 5                                     BICYCLE (OTHER)                   VTL
# 6                     BICYCLE INFRACTION (COMMERCIAL)   Administrative Code
# 7                                     BICYCLE NO BELL                   VTL
# 8                                   BICYCLE NO BRAKES                   VTL
# 9                                   BICYCLE NO LIGHTS                   VTL
# 10                          BICYCLE NO REFLECTOR VEST                   VTL
# ...

# %%
df.plot()

# %%
df['change'] = round((df['2016']-df['2009']) / df['2009']*100, 0)

# %%
df2 = df[df['2009'] > 100]

# %%
df2
# Out:
#                                              Violation                  Law  \
# 0                                       ACCEPT ON HAIL  Administrative Code
# 1                              AFTER HOURS CONSUMPTION                  ABC
# 2                       AGGRAVATED UNLICENSED OPERATOR                  VTL
# 6                      BICYCLE INFRACTION (COMMERCIAL)  Administrative Code
# 7                                      BICYCLE NO BELL                  VTL
# 12                                 BICYCLE ON SIDEWALK  Administrative Code
# 13                                        BIKE IN PARK            Park Regs
# 14                                          BOX CUTTER  Administrative Code
# 17    COMMERCIAL VEHICLES NO NAME OR ADDRESS DISPLAYED  Administrative Code
# 18                              CONSUMPTION OF ALCOHOL  Administrative Code
# 19                      CONSUMPTION OF ALCOHOL IN PARK            Park Regs
# ...

# %%
#df_top10 = df2.sort_values("Value", ascending=False).head(10)


df_top50 = df2.sort_values('change', inplace=True).head(50)
# Out:
# /Users/palar/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8896e59c38b0> in <module>()
#       2
#       3
# ----> 4 df_top50 = df2.sort_values('change', inplace=True).head(50)
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
df_top50

# %%
df_top50.plot(x='Violation', y='change', kind='barh')

# %%
df_top10 = df2.sort_values('change').head(10)

# %%
df_top10

# %%
ax = df_top10.plot(x='Violation', y='change', kind='barh')
ax.set_title("Top 10 reduction in Summons in NYC from 2009 to 2016, percentage", pad=10)

# %%
df_top10incr = df2.sort_values('change', ascending=False).head(10)

# %%
df2.sort_values('change', ascending=False).head(50)
# Out:
#                                              Violation                   Law  \
# 149                               OTHER NAVIGATION LAW        Navigation Law
# 170                           PICK UP HAIL IN BUS STOP   Administrative Code
# 84                                     KEY IN IGNITION   Administrative Code
# 131                          NON PAYMENT OF FARE (BUS)          Transit Regs
# 180                               REVOKED REGISTRATION                   VTL
# 157                    OTHER TAXI LIMOUSINE COMMISSION                   TLC
# 159                          OTHER TRANSIT REGULATIONS          Transit Regs
# 99                             MARIJUANA POSSESSION OF             Penal Law
# 232                                URINATING IN PUBLIC   Administrative Code
# 195                SOUND REPRODUCTION DEVICE-NO PERMIT   Administrative Code
# 58                               FIREWORKS POSSESS/USE             Penal Law
# ...

# %%
ax2 = df_top10incr.plot(x='Violation', y='change', kind='barh')
ax2.set_title("Top 10 increase in Summons in NYC from 2009 to 2016, percentage", pad=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-fd994cd5d985> in <module>()
# ----> 1 ax2 = df_top10incr.plot(x='Violation', y='change', kind='barh')
#       2 ax2.set_title("Top 10 increase in Summons in NYC from 2009 to 2016, percentage", pad=10)
#
# NameError: name 'df_top10incr' is not defined
