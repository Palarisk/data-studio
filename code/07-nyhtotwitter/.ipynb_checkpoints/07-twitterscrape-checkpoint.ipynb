# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler
import numpy as np

# %matplotlib inline

# %%
plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'axes.prop_cycle': cycler('color', ['#BA4D49']),#,'#4D6168','#F06560','#83A8AE','#E6B0A4','#C9CFAD']),
    'axes.spines.left'   : True,   
    'axes.spines.bottom' : False,
    'axes.spines.top'    : False,
    'axes.spines.right'  : False,
    'axes.labelcolor'  :'#4D6168',
    'axes.grid'           : True,
    'axes.axisbelow'      : True,
    
    'font.sans-serif': 'Arial Rounded MT Bold',
    'font.family': 'sans-serif',
    
    'text.color': '#4D6168',
    
    'xtick.color' : '#4D6168',
    'ytick.color' : '#4D6168',
    
    'grid.color':  '#83A8AE',
    
    'legend.edgecolor': 'white',
 
})

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://twitter.com/search?f=tweets&vertical=default&q=%23nyht%C3%B6kaura&src=typd")

# %%
#dates =  driver.find_elements_by_class_name("js-short-timestamp")  
#for date in dates:
#    print(date.text)

# %%
#This takes like 20 minutes
body = driver.find_element_by_tag_name("body")
time.sleep(1)

for _ in range(3000):
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.2)
    
dates =  driver.find_elements_by_class_name("js-short-timestamp")    

rows = []

for date in dates:
    row = {}
    row['date'] = date.text
    rows.append(row)

# %%
df = pd.DataFrame(rows)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b0ca3ebffeb2> in <module>()
# ----> 1 df = pd.DataFrame(rows)
#       2 df
#
# NameError: name 'rows' is not defined

# %%
df.to_csv('nyhto_twitter.csv')

# %%
#added the year 2018 in sublime and excel. created 2 separate files because the date was different format. Next I'll convert the dates to datetimeformat and then merge the to datarames back together
df = pd.read_csv("nyhto_twitter_edited.csv")
df2018 = pd.read_csv("nyhto_twitter_edited2018.csv")

# %%
df.head()
# Out:
#    index         date
# 0    213  30 Dec 2017
# 1    214  30 Dec 2017
# 2    215  28 Dec 2017
# 3    216  22 Dec 2017
# 4    217  22 Dec 2017

# %%
df2018['date'] = pd.to_datetime(df2018['date'], format="%b %d %Y")

# %%
df['date'] = pd.to_datetime(df['date'], format="%d %b %Y")

# %%
df.head()
# Out:
#    index       date
# 0    213 2017-12-30
# 1    214 2017-12-30
# 2    215 2017-12-28
# 3    216 2017-12-22
# 4    217 2017-12-22

# %%
df2018.head()
# Out:
#    index       date
# 0      0 2018-08-19
# 1      1 2018-08-19
# 2      2 2018-08-15
# 3      3 2018-08-15
# 4      4 2018-08-15

# %%
frames = [df, df2018]
df = pd.concat(frames)
df
# Out:
#      index       date
# 0      213 2017-12-30
# 1      214 2017-12-30
# 2      215 2017-12-28
# 3      216 2017-12-22
# 4      217 2017-12-22
# 5      218 2017-12-22
# 6      219 2017-12-21
# 7      220 2017-12-20
# 8      221 2017-12-18
# 9      222 2017-12-18
# 10     223 2017-12-17
# 11     224 2017-12-15
# 12     225 2017-12-14
# 13     226 2017-12-14
# 14     227 2017-12-11
# 15     228 2017-12-07
# 16     229 2017-12-03
# 17     230 2017-12-01
# 18     231 2017-11-30
# 19     232 2017-11-30
# 20     233 2017-11-29
# 21     234 2017-11-29
# 22     235 2017-11-28
# 23     236 2017-11-27
# 24     237 2017-11-26
# 25     238 2017-11-23
# 26     239 2017-11-23
# 27     240 2017-11-22
# 28     241 2017-11-22
# 29     242 2017-11-22
# ..     ...        ...
# 183    183 2018-01-21
# 184    184 2018-01-20
# 185    185 2018-01-20
# 186    186 2018-01-20
# 187    187 2018-01-19
# 188    188 2018-01-19
# 189    189 2018-01-19
# 190    190 2018-01-19
# 191    191 2018-01-19
# ...

# %%
ax = df.resample('M', on="date").count().date.plot()
ax.grid(False, axis='x')
ax.xaxis.label.set_visible(False)
ax.set_yticks([100,200,600])
ax.set_yticklabels(["100","200","600 tweets\nin a month\nwith #nyhtökaura"])
ax.set_title('The Rise and Fall of the "Nyhtökaura" Hype in Twitter', pad=20, fontsize=13, loc='left')
plt.show()

# %%
df_fb = pd.read_csv("nyhto_fb.csv")

# %%
df_fb
# Out:
#          dates  dates.1
# 0   2016-07-31       77
# 1   2016-08-31      110
# 2   2016-09-30       90
# 3   2016-10-31       68
# 4   2016-11-30       77
# 5   2016-12-31       63
# 6   2017-01-31       23
# 7   2017-02-28       29
# 8   2017-03-31       48
# 9   2017-04-30       26
# 10  2017-05-31        4
# 11  2017-06-30        1
# 12  2017-07-31        1
# 13  2017-08-31        0
# 14  2017-09-30        3
# 15  2017-10-31        3
# 16  2017-11-30        1

# %%
df_twitter_m = df.resample('M', on="date").count()

# %%
df_twitter_m
# Out:
#             index  date
# date
# 2015-11-30      2     2
# 2015-12-31      7     7
# 2016-01-31    213   213
# 2016-02-29    106   106
# 2016-03-31     70    70
# 2016-04-30    138   138
# 2016-05-31    654   654
# 2016-06-30    262   262
# 2016-07-31    182   182
# 2016-08-31    214   214
# 2016-09-30    271   271
# 2016-10-31    148   148
# 2016-11-30    117   117
# 2016-12-31    157   157
# 2017-01-31     56    56
# 2017-02-28     61    61
# 2017-03-31     86    86
# 2017-04-30     73    73
# 2017-05-31    106   106
# 2017-06-30     25    25
# 2017-07-31     47    47
# 2017-08-31     45    45
# 2017-09-30     25    25
# 2017-10-31     51    51
# 2017-11-30     44    44
# 2017-12-31     18    18
# 2018-01-31     37    37
# 2018-02-28     32    32
# 2018-03-31     62    62
# 2018-04-30     16    16
# 2018-05-31     18    18
# 2018-06-30     13    13
# 2018-07-31     18    18
# 2018-08-31     17    17

# %%
df_twitter_m.dtypes
df_twitter_m.to_csv('nyhto_twitter_m.csv')

# %%
df_twitter_m = pd.read_csv("nyhto_twitter_m2.csv")

# %%
df_twitter_m
# Out:
#           date  tweets1  tweets2
# 0   2015-11-30        2        2
# 1   2015-12-31        7        7
# 2   2016-01-31      213      213
# 3   2016-02-29      106      106
# 4   2016-03-31       70       70
# 5   2016-04-30      138      138
# 6   2016-05-31      654      654
# 7   2016-06-30      262      262
# 8   2016-07-31      182      182
# 9   2016-08-31      214      214
# 10  2016-09-30      271      271
# 11  2016-10-31      148      148
# 12  2016-11-30      117      117
# 13  2016-12-31      157      157
# 14  2017-01-31       56       56
# 15  2017-02-28       61       61
# 16  2017-03-31       86       86
# 17  2017-04-30       73       73
# 18  2017-05-31      106      106
# 19  2017-06-30       25       25
# 20  2017-07-31       47       47
# 21  2017-08-31       45       45
# 22  2017-09-30       25       25
# 23  2017-10-31       51       51
# 24  2017-11-30       44       44
# 25  2017-12-31       18       18
# 26  2018-01-31       37       37
# ...

# %%
df_all = df_twitter_m.merge(df_fb, left_on='date', right_on='dates', how='outer')

# %%
df_all
# Out:
#           date  tweets1  tweets2       dates  dates.1
# 0   2015-11-30        2        2         NaN      NaN
# 1   2015-12-31        7        7         NaN      NaN
# 2   2016-01-31      213      213         NaN      NaN
# 3   2016-02-29      106      106         NaN      NaN
# 4   2016-03-31       70       70         NaN      NaN
# 5   2016-04-30      138      138         NaN      NaN
# 6   2016-05-31      654      654         NaN      NaN
# 7   2016-06-30      262      262         NaN      NaN
# 8   2016-07-31      182      182  2016-07-31     77.0
# 9   2016-08-31      214      214  2016-08-31    110.0
# 10  2016-09-30      271      271  2016-09-30     90.0
# 11  2016-10-31      148      148  2016-10-31     68.0
# 12  2016-11-30      117      117  2016-11-30     77.0
# 13  2016-12-31      157      157  2016-12-31     63.0
# 14  2017-01-31       56       56  2017-01-31     23.0
# 15  2017-02-28       61       61  2017-02-28     29.0
# ...

# %%
plt.plot('date', 'tweets1', label='tweets')
plt.plot('date', "dates.1", label='FB posts')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-e1b331513fa0> in <module>()
# ----> 1 plt.plot('date', 'tweets1', label='tweets')
#       2 plt.plot('date', "dates.1", label='FB posts')
#       3 plt.legend(loc='best')
#       4 plt.show()
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
# ...
